# %% [markdown]
# # Data 602 Homework

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'multiTimeline.csv')

# %%
df
# Out:
#        Month  Diet  Gym  Finance
# 0    2004-01   100   31       48
# 1    2004-02    75   26       49
# 2    2004-03    67   24       47
# 3    2004-04    70   22       48
# 4    2004-05    72   22       43
# ..       ...   ...  ...      ...
# 163  2017-08    46   52       43
# 164  2017-09    44   50       47
# 165  2017-10    44   47       45
# 166  2017-11    41   47       47
# 167  2017-12    39   45       56
#
# [168 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Month    168 non-null    object
#  1   Diet     168 non-null    int64
#  2   Gym      168 non-null    int64
#  3   Finance  168 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 5.4+ KB

# %%
df['Month'] =  pd.to_datetime(df['Month'])

# %%
df.set_index('Month',inplace=True)

# %%
df.head()
# Out:
#             Diet  Gym  Finance
# Month
# 2004-01-01   100   31       48
# 2004-02-01    75   26       49
# 2004-03-01    67   24       47
# 2004-04-01    70   22       48
# 2004-05-01    72   22       43

# %% [markdown]
# ## General Visualisation of the graph:

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Diet, linewidth=1)
plt.plot(df.Gym, linewidth=1)
plt.plot(df.Finance,linewidth=1)
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('General Visualization Trends:')
plt.legend(['Diet', 'Gym', 'Finance'])
plt.show()

# %% [markdown]
# ## Diet Rolling Average Visualisation:

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Diet.rolling(15).mean())
plt.xlabel('Year')
plt.ylabel('People')
plt.legend(labels=['Diet'])
plt.title('Diet Visualisation:')
plt.show()

# %% [markdown]
# ## Gym Rolling Average Visualisation:

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Gym.rolling(15).mean())
plt.xlabel('Year')
plt.ylabel('People')
plt.legend(labels=['Gym'])
plt.title('Gym Visualisation:')
plt.show()

# %% [markdown]
# ## Compasrison of Gym and Diet:

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Gym.rolling(15).mean())
plt.plot(df.Diet.rolling(15).mean())
plt.xlabel('Year')
plt.ylabel('People')
plt.legend(labels=['Gym','Diet'])
plt.title('GYM AND DIET COMPASRISON VISUALISATION:')
plt.show()

# %% [markdown]
# ## First OrderDifferencing:

# %%
diet = df[['Diet']]
diet.diff().plot(figsize=(12,6), linewidth=1)
plt.xlabel('Year');

# %%
df.corr()
# Out:
#              Diet       Gym   Finance
# Diet     1.000000 -0.100764 -0.034639
# Gym     -0.100764  1.000000 -0.284279
# Finance -0.034639 -0.284279  1.000000

# %% [markdown]
# ## Corelation amongst the varaibles:

# %%
df.diff().plot(figsize=(12,6), linewidth=1)
plt.xlabel('Year');

# %%
df.diff().corr()
# Out:
#              Diet       Gym   Finance
# Diet     1.000000  0.758707  0.373828
# Gym      0.758707  1.000000  0.301111
# Finance  0.373828  0.301111  1.000000

# %% [markdown]
# ## Auto-corelation Plot:

# %%
pd.plotting.autocorrelation_plot(df['Diet']);

# %% [markdown]
# The statistical significance of the correlation is indicated by the dotted lines in the accompanying plot. In this scenario, the 'diet' series can be said to be legitimately autocorrelated with a twelve-month lag.

# %% [markdown]
# ## Seasonality:
# Seasonality is a property of a time series in which the data undergoes predictable and recurring changes across the calendar year. Seasonal refers to any predictable variation or pattern that recurs or repeats over a one-year period.
